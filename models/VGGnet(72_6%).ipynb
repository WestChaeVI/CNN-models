# %% [markdown]
# <a href="https://colab.research.google.com/github/WestChaeVI/CNN-models/blob/main/models/VGGnet(72_6%25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VGGNet (val acc : 72.6 %)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CV_seminar_project
# Out:
# /content/drive/MyDrive/CV_seminar_project

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu' # device 배정
torch.manual_seed(42)
if device == 'cuda':
  torch.cuda.manual_seed_all(42)
device
# Out:
# 'cuda'

# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
from tensorflow.keras.optimizers import Adam,SGD
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec

# %% [markdown]
# # Preparing Dataset

# %%
from sklearn.utils import shuffle

def get_images(root_path):
    Images = []
    Labels = []  # 0:'dolphin', 1:'shark', 2:'whale'
    label = 0
    
    for labels in os.listdir(root_path):

      if labels == 'dolphin':
          label = 0
      elif labels == 'shark':
          label = 1
      elif labels == 'whale':
          label = 2
      
      
      for image_file in os.listdir(root_path + '/' + labels):
          image = cv2.imread(root_path+ '/' + labels + '/' + image_file) 
          image = cv2.resize(image,(224,224),interpolation=cv2.INTER_AREA) 
          Images.append(image)
          Labels.append(label)

    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

# %%
root_path = '/content/drive/MyDrive/CV_seminar_project/original'
Images,Labels = get_images(root_path)
Images = np.array(Images) #converting the list of images to numpy array.
Labels = np.array(Labels)

# %% [markdown]
# # Model (VGGNet19)

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(32,kernel_size=(3,3),padding='same',activation='relu',input_shape=(224,224,3), kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())
model.add(Layers.Conv2D(32,kernel_size=(3,3),padding='same',activation='relu', kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())

model.add(Layers.MaxPool2D(3,3))

    
model.add(Layers.Conv2D(64,kernel_size=(3,3),padding='same',activation='relu', kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())
model.add(Layers.Conv2D(64,kernel_size=(3,3),padding='same',activation='relu', kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())
model.add(Layers.Conv2D(64,kernel_size=(3,3),padding='same',activation='relu', kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())

model.add(Layers.MaxPool2D(3,3))


model.add(Layers.Conv2D(128,kernel_size=(3,3),activation='relu',padding = 'same', kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())
model.add(Layers.Conv2D(128,kernel_size=(3,3),activation='relu',padding = 'same', kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())
model.add(Layers.Conv2D(128,kernel_size=(3,3),activation='relu',padding = 'same', kernel_initializer='he_normal'))
model.add(Layers.BatchNormalization())

model.add(Layers.MaxPool2D(3,3))


model.add(Layers.GlobalAveragePooling2D())
model.add(Layers.Dense(200,activation='relu', kernel_initializer='he_normal'))
model.add(Layers.Dropout(rate=0.8))
model.add(Layers.Dense(3,activation='softmax')) # Fine Tuning 

model.compile(optimizer=Optimizer.Adam(lr=0.0005),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 224, 224, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 74, 74, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 74, 74, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 74, 74, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 74, 74, 64)       256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 74, 74, 64)        36928
#
#  batch_normalization_4 (Batc  (None, 74, 74, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 24, 24, 128)       73856
#
#  batch_normalization_5 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_6 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_7 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 200)               25800
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense_1 (Dense)             (None, 3)                 603
#
# =================================================================
# Total params: 500,483
# Trainable params: 499,203
# Non-trainable params: 1,280
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
trained = model.fit(Images,Labels,epochs=100,validation_split=0.20)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 20s 180ms/step - loss: 2.0474 - accuracy: 0.3794 - val_loss: 69.4971 - val_accuracy: 0.3878
# Epoch 2/100
# 33/33 [==============================] - 4s 115ms/step - loss: 1.3542 - accuracy: 0.4366 - val_loss: 11.4904 - val_accuracy: 0.2852
# Epoch 3/100
# 33/33 [==============================] - 4s 110ms/step - loss: 1.1918 - accuracy: 0.4500 - val_loss: 2.2921 - val_accuracy: 0.3726
# Epoch 4/100
# 33/33 [==============================] - 4s 113ms/step - loss: 1.1430 - accuracy: 0.4528 - val_loss: 1.2863 - val_accuracy: 0.4639
# Epoch 5/100
# 33/33 [==============================] - 4s 115ms/step - loss: 1.0762 - accuracy: 0.4538 - val_loss: 1.0126 - val_accuracy: 0.4715
# Epoch 6/100
# 33/33 [==============================] - 4s 114ms/step - loss: 1.0497 - accuracy: 0.4719 - val_loss: 0.9632 - val_accuracy: 0.5133
# Epoch 7/100
# 33/33 [==============================] - 4s 110ms/step - loss: 1.0485 - accuracy: 0.4766 - val_loss: 0.9494 - val_accuracy: 0.4943
# Epoch 8/100
# 33/33 [==============================] - 4s 111ms/step - loss: 1.0307 - accuracy: 0.5071 - val_loss: 0.9590 - val_accuracy: 0.4753
# Epoch 9/100
# 33/33 [==============================] - 4s 116ms/step - loss: 1.0003 - accuracy: 0.4986 - val_loss: 0.9395 - val_accuracy: 0.5133
# Epoch 10/100
# 33/33 [==============================] - 4s 114ms/step - loss: 1.0052 - accuracy: 0.5014 - val_loss: 0.9664 - val_accuracy: 0.5361
# Epoch 11/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.9800 - accuracy: 0.5081 - val_loss: 0.9409 - val_accuracy: 0.5399
# Epoch 12/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.9908 - accuracy: 0.5138 - val_loss: 0.9250 - val_accuracy: 0.5399
# Epoch 13/100
# 33/33 [==============================] - 4s 113ms/step - loss: 0.9798 - accuracy: 0.5224 - val_loss: 0.9622 - val_accuracy: 0.5247
# Epoch 14/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.9673 - accuracy: 0.5310 - val_loss: 0.9336 - val_accuracy: 0.5019
# Epoch 15/100
# 33/33 [==============================] - 4s 112ms/step - loss: 0.9557 - accuracy: 0.5462 - val_loss: 0.8991 - val_accuracy: 0.5323
# Epoch 16/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.9522 - accuracy: 0.5510 - val_loss: 0.9401 - val_accuracy: 0.5361
# Epoch 17/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.9614 - accuracy: 0.5500 - val_loss: 0.9592 - val_accuracy: 0.5361
# Epoch 18/100
# 33/33 [==============================] - 4s 117ms/step - loss: 0.9433 - accuracy: 0.5672 - val_loss: 0.8855 - val_accuracy: 0.5589
# Epoch 19/100
# 33/33 [==============================] - 4s 111ms/step - loss: 0.9196 - accuracy: 0.5767 - val_loss: 0.8709 - val_accuracy: 0.5627
# Epoch 20/100
# 33/33 [==============================] - 4s 117ms/step - loss: 0.9181 - accuracy: 0.5729 - val_loss: 0.9097 - val_accuracy: 0.5703
# Epoch 21/100
# 33/33 [==============================] - 4s 112ms/step - loss: 0.8816 - accuracy: 0.5958 - val_loss: 0.9319 - val_accuracy: 0.5057
# Epoch 22/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.8853 - accuracy: 0.6015 - val_loss: 1.0661 - val_accuracy: 0.5513
# Epoch 23/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.8508 - accuracy: 0.6101 - val_loss: 1.0505 - val_accuracy: 0.5513
# Epoch 24/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.8210 - accuracy: 0.6311 - val_loss: 1.0150 - val_accuracy: 0.5475
# Epoch 25/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.8787 - accuracy: 0.5968 - val_loss: 1.0087 - val_accuracy: 0.5361
# Epoch 26/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.8534 - accuracy: 0.6177 - val_loss: 0.8884 - val_accuracy: 0.5513
# Epoch 27/100
# 33/33 [==============================] - 4s 117ms/step - loss: 0.7816 - accuracy: 0.6673 - val_loss: 0.8425 - val_accuracy: 0.6046
# Epoch 28/100
# 33/33 [==============================] - 4s 113ms/step - loss: 0.7959 - accuracy: 0.6635 - val_loss: 0.7801 - val_accuracy: 0.6274
# Epoch 29/100
# 33/33 [==============================] - 4s 112ms/step - loss: 0.7390 - accuracy: 0.6740 - val_loss: 0.8768 - val_accuracy: 0.6502
# Epoch 30/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.7434 - accuracy: 0.6711 - val_loss: 0.8448 - val_accuracy: 0.6046
# Epoch 31/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.7743 - accuracy: 0.6597 - val_loss: 1.0492 - val_accuracy: 0.5285
# Epoch 32/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.7457 - accuracy: 0.6625 - val_loss: 0.8128 - val_accuracy: 0.6502
# Epoch 33/100
# 33/33 [==============================] - 4s 117ms/step - loss: 0.6879 - accuracy: 0.7016 - val_loss: 0.8021 - val_accuracy: 0.6616
# Epoch 34/100
# 33/33 [==============================] - 4s 119ms/step - loss: 0.6554 - accuracy: 0.7083 - val_loss: 0.9246 - val_accuracy: 0.6122
# Epoch 35/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.6778 - accuracy: 0.7016 - val_loss: 0.8586 - val_accuracy: 0.6540
# Epoch 36/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.6901 - accuracy: 0.7007 - val_loss: 0.9784 - val_accuracy: 0.5856
# Epoch 37/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.6411 - accuracy: 0.7302 - val_loss: 0.8960 - val_accuracy: 0.6502
# Epoch 38/100
# 33/33 [==============================] - 4s 119ms/step - loss: 0.6527 - accuracy: 0.7264 - val_loss: 1.0819 - val_accuracy: 0.5894
# Epoch 39/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.6120 - accuracy: 0.7436 - val_loss: 0.9954 - val_accuracy: 0.6084
# Epoch 40/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.6043 - accuracy: 0.7436 - val_loss: 0.8551 - val_accuracy: 0.6616
# Epoch 41/100
# 33/33 [==============================] - 4s 119ms/step - loss: 0.5349 - accuracy: 0.7655 - val_loss: 1.1595 - val_accuracy: 0.5970
# Epoch 42/100
# 33/33 [==============================] - 4s 120ms/step - loss: 0.5353 - accuracy: 0.7779 - val_loss: 1.2759 - val_accuracy: 0.5703
# Epoch 43/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.5874 - accuracy: 0.7636 - val_loss: 0.9648 - val_accuracy: 0.6388
# Epoch 44/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.5365 - accuracy: 0.7922 - val_loss: 1.1117 - val_accuracy: 0.6122
# Epoch 45/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.4920 - accuracy: 0.8036 - val_loss: 0.9604 - val_accuracy: 0.6274
# Epoch 46/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.4747 - accuracy: 0.8074 - val_loss: 0.8839 - val_accuracy: 0.6654
# Epoch 47/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.5108 - accuracy: 0.8017 - val_loss: 1.2518 - val_accuracy: 0.5589
# Epoch 48/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.4240 - accuracy: 0.8351 - val_loss: 1.2557 - val_accuracy: 0.6464
# Epoch 49/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.3842 - accuracy: 0.8561 - val_loss: 1.1386 - val_accuracy: 0.6578
# Epoch 50/100
# 33/33 [==============================] - 4s 119ms/step - loss: 0.3940 - accuracy: 0.8456 - val_loss: 1.1009 - val_accuracy: 0.6464
# Epoch 51/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.4568 - accuracy: 0.8418 - val_loss: 1.1150 - val_accuracy: 0.6388
# Epoch 52/100
# 33/33 [==============================] - 4s 119ms/step - loss: 0.4630 - accuracy: 0.8189 - val_loss: 1.0177 - val_accuracy: 0.6616
# Epoch 53/100
# 33/33 [==============================] - 4s 119ms/step - loss: 0.3290 - accuracy: 0.8818 - val_loss: 1.0238 - val_accuracy: 0.6882
# Epoch 54/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.2969 - accuracy: 0.8837 - val_loss: 0.8855 - val_accuracy: 0.7186
# Epoch 55/100
# 33/33 [==============================] - 4s 117ms/step - loss: 0.2849 - accuracy: 0.8885 - val_loss: 1.3192 - val_accuracy: 0.6426
# Epoch 56/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.2829 - accuracy: 0.8990 - val_loss: 1.0932 - val_accuracy: 0.7072
# Epoch 57/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.2779 - accuracy: 0.8856 - val_loss: 1.5849 - val_accuracy: 0.6122
# Epoch 58/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.3189 - accuracy: 0.8761 - val_loss: 1.7280 - val_accuracy: 0.6160
# Epoch 59/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.3036 - accuracy: 0.8665 - val_loss: 1.2043 - val_accuracy: 0.6958
# Epoch 60/100
# 33/33 [==============================] - 4s 117ms/step - loss: 0.2593 - accuracy: 0.9113 - val_loss: 1.0727 - val_accuracy: 0.6616
# Epoch 61/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1720 - accuracy: 0.9342 - val_loss: 1.0964 - val_accuracy: 0.6844
# Epoch 62/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1757 - accuracy: 0.9380 - val_loss: 1.5996 - val_accuracy: 0.6426
# Epoch 63/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.2116 - accuracy: 0.9276 - val_loss: 1.3602 - val_accuracy: 0.6578
# Epoch 64/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.2038 - accuracy: 0.9333 - val_loss: 2.6753 - val_accuracy: 0.5475
# Epoch 65/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.2199 - accuracy: 0.9304 - val_loss: 1.3264 - val_accuracy: 0.6426
# Epoch 66/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1962 - accuracy: 0.9399 - val_loss: 1.8993 - val_accuracy: 0.6350
# Epoch 67/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.1905 - accuracy: 0.9314 - val_loss: 1.6089 - val_accuracy: 0.6806
# Epoch 68/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1370 - accuracy: 0.9581 - val_loss: 1.2037 - val_accuracy: 0.7262
# Epoch 69/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.1390 - accuracy: 0.9590 - val_loss: 1.2033 - val_accuracy: 0.6920
# Epoch 70/100
# 33/33 [==============================] - 4s 119ms/step - loss: 0.1410 - accuracy: 0.9590 - val_loss: 1.4141 - val_accuracy: 0.6958
# Epoch 71/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1892 - accuracy: 0.9428 - val_loss: 1.4722 - val_accuracy: 0.6768
# Epoch 72/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1932 - accuracy: 0.9409 - val_loss: 2.1540 - val_accuracy: 0.5970
# Epoch 73/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.1274 - accuracy: 0.9619 - val_loss: 1.8620 - val_accuracy: 0.6426
# Epoch 74/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.0668 - accuracy: 0.9781 - val_loss: 1.5493 - val_accuracy: 0.6502
# Epoch 75/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0500 - accuracy: 0.9847 - val_loss: 1.6395 - val_accuracy: 0.6464
# Epoch 76/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0730 - accuracy: 0.9704 - val_loss: 1.3569 - val_accuracy: 0.7186
# Epoch 77/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.1095 - accuracy: 0.9666 - val_loss: 1.6696 - val_accuracy: 0.6958
# Epoch 78/100
# 33/33 [==============================] - 4s 116ms/step - loss: 0.1447 - accuracy: 0.9504 - val_loss: 2.5002 - val_accuracy: 0.6464
# Epoch 79/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.1203 - accuracy: 0.9590 - val_loss: 1.6074 - val_accuracy: 0.7110
# Epoch 80/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1065 - accuracy: 0.9657 - val_loss: 1.8962 - val_accuracy: 0.6502
# Epoch 81/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.0914 - accuracy: 0.9733 - val_loss: 2.0534 - val_accuracy: 0.6882
# Epoch 82/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0782 - accuracy: 0.9733 - val_loss: 1.9420 - val_accuracy: 0.6730
# Epoch 83/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.0823 - accuracy: 0.9771 - val_loss: 2.2548 - val_accuracy: 0.6806
# Epoch 84/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1052 - accuracy: 0.9628 - val_loss: 2.0854 - val_accuracy: 0.7224
# Epoch 85/100
# 33/33 [==============================] - 4s 120ms/step - loss: 0.0835 - accuracy: 0.9714 - val_loss: 1.8132 - val_accuracy: 0.7034
# Epoch 86/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.0678 - accuracy: 0.9781 - val_loss: 1.6143 - val_accuracy: 0.6692
# Epoch 87/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0593 - accuracy: 0.9847 - val_loss: 1.9583 - val_accuracy: 0.6274
# Epoch 88/100
# 33/33 [==============================] - 4s 120ms/step - loss: 0.0598 - accuracy: 0.9790 - val_loss: 1.4277 - val_accuracy: 0.6996
# Epoch 89/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.0743 - accuracy: 0.9847 - val_loss: 2.4990 - val_accuracy: 0.6274
# Epoch 90/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1267 - accuracy: 0.9600 - val_loss: 1.6037 - val_accuracy: 0.7034
# Epoch 91/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.1097 - accuracy: 0.9695 - val_loss: 2.6328 - val_accuracy: 0.6008
# Epoch 92/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.0883 - accuracy: 0.9752 - val_loss: 1.5187 - val_accuracy: 0.6996
# Epoch 93/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.0740 - accuracy: 0.9762 - val_loss: 1.4948 - val_accuracy: 0.6996
# Epoch 94/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.0488 - accuracy: 0.9828 - val_loss: 2.3744 - val_accuracy: 0.6008
# Epoch 95/100
# 33/33 [==============================] - 4s 120ms/step - loss: 0.0655 - accuracy: 0.9771 - val_loss: 1.6484 - val_accuracy: 0.6920
# Epoch 96/100
# 33/33 [==============================] - 4s 117ms/step - loss: 0.0665 - accuracy: 0.9790 - val_loss: 2.0121 - val_accuracy: 0.6274
# Epoch 97/100
# 33/33 [==============================] - 4s 114ms/step - loss: 0.1394 - accuracy: 0.9581 - val_loss: 2.2618 - val_accuracy: 0.6426
# Epoch 98/100
# 33/33 [==============================] - 4s 115ms/step - loss: 0.2241 - accuracy: 0.9399 - val_loss: 3.7492 - val_accuracy: 0.5703
# Epoch 99/100
# 33/33 [==============================] - 4s 121ms/step - loss: 0.0867 - accuracy: 0.9743 - val_loss: 1.4446 - val_accuracy: 0.7034
# Epoch 100/100
# 33/33 [==============================] - 4s 118ms/step - loss: 0.0800 - accuracy: 0.9743 - val_loss: 1.6281 - val_accuracy: 0.6958

# %%
best_epoch = []
for i, acc in enumerate(trained.history['val_accuracy']):
  if acc == max(trained.history['val_accuracy']):
      best_epoch.append(i+1)
best_epoch = best_epoch[0]
best_epoch
# Out:
# 68

# %% [markdown]
# # Acc & Loss Plot

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(30,7),facecolor='black')
plt = fig.subplots(1,2)

train_score = {'Acc':trained.history['accuracy'], 'Loss':trained.history['loss']}
valid_score = {'Acc':trained.history['val_accuracy'], 'Loss':trained.history['val_loss']}

for i in range(len(train_score)):
  plt[i].plot(train_score[list(train_score.keys())[i]], c='cyan')
  plt[i].plot(valid_score[list(valid_score.keys())[i]],c='magenta')
  plt[i].set_title(list(valid_score.keys())[i],color='white', fontweight='bold', fontsize=30)
  plt[i].set_ylabel(list(valid_score.keys())[i],color='white', fontweight='bold', fontsize=20)
  plt[i].set_xlabel('Epoch',color='white', fontweight='bold', fontsize=20)
  if i == 0:
    plt[i].set_ylim([0.3,1])
  else:
    plt[i].set_ylim([0,2])

  plt[i].set_xlim([-1, 100])
  plt[i].legend(['Train', 'Test'], loc='upper left')
  plt[i].axvline(x=best_epoch, color='r', linestyle=':')
  plt[i].tick_params(axis='x', colors='white')
  plt[i].tick_params(axis='y', colors='white')
  plt[i].patch.set_facecolor('#212529')
  arrowprops = dict(fc='white', color='red',arrowstyle="-|>")
  font1 = {'family': 'serif',
      'color':  'darkred',
      'weight': 'normal',
      'size': 16}
  plt[i].text(best_epoch-40,0.5, "Best Epoch : {}".format(best_epoch), 
              fontdict= {'color':  'white','weight': 'bold','size': 20})
  plt[i].annotate("",xy=(best_epoch-1, 0.49),
                  xytext=(best_epoch-40,0.49),
                  arrowprops=arrowprops)

# %%
print('100 epcohs 중 validset 기준 accuracy {} % 성능을 달성하였습니다.'.format(round(max(trained.history['val_accuracy']),3)*100))
# Out:
# 100 epcohs 중 validset 기준 accuracy 72.6 % 성능을 달성하였습니다.
